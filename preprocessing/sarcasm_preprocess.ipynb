# %%
df_sarcasm = pd.read_json("Sarcasm_Headlines_Dataset_v2.json", lines=True)
df_sarcasm = df_sarcasm.rename(columns={'headline': 'text'})
df_sarcasm['label'] = 2

# %%
df_sarcasm.to_csv("sarcasm_processed.csv", index=False)
